# %% [markdown]
# # 01 - Tuto xarray

# %% [markdown]
# This notebook is set to familiarize with the `xarray` package that you will have to use in other notebooks.

# %% [markdown]
# ## Constraints
#
# + 🚨 Only cells with the comment `# NOTE: Fill me!` should be filled
# + 🚨 Notebook should be saved and commited **with** outputs for the submission
#
#
# + ⚠️ The solution only requires packages listed in the `requirements/requirements.txt`
#
# ## Note
#
# + The `assert` statements in the notebook are here to guide the project.
# However, successful `assert` statements does not guarantee that your code is correct.

# %%
# !pip install -r requirements/requirements.txt
# Out:
# Requirement already satisfied: jupyter==1.0.0 in c:\users\raque\anaconda3\lib\site-packages (from -r requirements/requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\raque\anaconda3\lib\site-packages (from -r requirements/requirements.txt (line 2)) (3.7.4)
# Requirement already satisfied: netCDF4>=1.6.0 in c:\users\raque\anaconda3\lib\site-packages (from -r requirements/requirements.txt (line 3)) (1.6.5)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\raque\anaconda3\lib\site-packages (from -r requirements/requirements.txt (line 4)) (1.23.5)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\raque\anaconda3\lib\site-packages (from -r requirements/requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: pathlib2==2.3.7.post1 in c:\users\raque\anaconda3\lib\site-packages (from -r requirements/requirements.txt (line 6)) (2.3.7.post1)
# Requirement already satisfied: scipy==1.9.3 in c:\users\raque\anaconda3\lib\site-packages (from -r requirements/requirements.txt (line 7)) (1.9.3)
# Requirement already satisfied: xarray>=2022.6.0 in c:\users\raque\anaconda3\lib\site-packages (from -r requirements/requirements.txt (line 8)) (2023.1.0)
# Requirement already satisfied: notebook in c:\users\raque\anaconda3\lib\site-packages (from jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (6.1.4)
# Requirement already satisfied: qtconsole in c:\users\raque\anaconda3\lib\site-packages (from jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (4.7.7)
# Requirement already satisfied: jupyter-console in c:\users\raque\anaconda3\lib\site-packages (from jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (6.2.0)
# Requirement already satisfied: nbconvert in c:\users\raque\anaconda3\lib\site-packages (from jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (6.0.7)
# Requirement already satisfied: ipykernel in c:\users\raque\anaconda3\lib\site-packages (from jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (5.3.4)
# Requirement already satisfied: ipywidgets in c:\users\raque\anaconda3\lib\site-packages (from jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (7.5.1)
# Requirement already satisfied: six in c:\users\raque\anaconda3\lib\site-packages (from pathlib2==2.3.7.post1->-r requirements/requirements.txt (line 6)) (1.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\raque\anaconda3\lib\site-packages (from matplotlib>=3.6.0->-r requirements/requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\raque\anaconda3\lib\site-packages (from matplotlib>=3.6.0->-r requirements/requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raque\anaconda3\lib\site-packages (from matplotlib>=3.6.0->-r requirements/requirements.txt (line 2)) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\raque\anaconda3\lib\site-packages (from matplotlib>=3.6.0->-r requirements/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\raque\anaconda3\lib\site-packages (from matplotlib>=3.6.0->-r requirements/requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\raque\anaconda3\lib\site-packages (from matplotlib>=3.6.0->-r requirements/requirements.txt (line 2)) (8.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\raque\anaconda3\lib\site-packages (from matplotlib>=3.6.0->-r requirements/requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\raque\anaconda3\lib\site-packages (from matplotlib>=3.6.0->-r requirements/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\raque\anaconda3\lib\site-packages (from matplotlib>=3.6.0->-r requirements/requirements.txt (line 2)) (6.1.1)
# Requirement already satisfied: cftime in c:\users\raque\anaconda3\lib\site-packages (from netCDF4>=1.6.0->-r requirements/requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: certifi in c:\users\raque\anaconda3\lib\site-packages (from netCDF4>=1.6.0->-r requirements/requirements.txt (line 3)) (2020.6.20)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raque\anaconda3\lib\site-packages (from pandas>=1.5.0->-r requirements/requirements.txt (line 5)) (2020.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\raque\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6.0->-r requirements/requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\raque\anaconda3\lib\site-packages (from ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (7.19.0)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\raque\anaconda3\lib\site-packages (from ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (5.0.5)
# Requirement already satisfied: jupyter-client in c:\users\raque\anaconda3\lib\site-packages (from ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in c:\users\raque\anaconda3\lib\site-packages (from ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\raque\anaconda3\lib\site-packages (from ipywidgets->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (5.0.8)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\raque\anaconda3\lib\site-packages (from ipywidgets->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (3.5.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\raque\anaconda3\lib\site-packages (from jupyter-console->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (3.0.8)
# Requirement already satisfied: pygments in c:\users\raque\anaconda3\lib\site-packages (from jupyter-console->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (2.7.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\raque\anaconda3\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: jinja2>=2.4 in c:\users\raque\anaconda3\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (2.11.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\raque\anaconda3\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: jupyter-core in c:\users\raque\anaconda3\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (4.6.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\raque\anaconda3\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.3)
# Requirement already satisfied: bleach in c:\users\raque\anaconda3\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\raque\anaconda3\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (1.4.3)
# Requirement already satisfied: testpath in c:\users\raque\anaconda3\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: defusedxml in c:\users\raque\anaconda3\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\raque\anaconda3\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\raque\anaconda3\lib\site-packages (from notebook->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (19.0.2)
# Requirement already satisfied: argon2-cffi in c:\users\raque\anaconda3\lib\site-packages (from notebook->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (20.1.0)
# Requirement already satisfied: ipython-genutils in c:\users\raque\anaconda3\lib\site-packages (from notebook->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: Send2Trash in c:\users\raque\anaconda3\lib\site-packages (from notebook->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\raque\anaconda3\lib\site-packages (from notebook->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.9.1)
# Requirement already satisfied: prometheus-client in c:\users\raque\anaconda3\lib\site-packages (from notebook->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: qtpy in c:\users\raque\anaconda3\lib\site-packages (from qtconsole->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\raque\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (50.3.1.post20201107)
# Requirement already satisfied: jedi>=0.10 in c:\users\raque\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.17.1)
# Requirement already satisfied: decorator in c:\users\raque\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (4.4.2)
# Requirement already satisfied: pickleshare in c:\users\raque\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: backcall in c:\users\raque\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: colorama in c:\users\raque\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\raque\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\raque\anaconda3\lib\site-packages (from jupyter-core->nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (227)
# Requirement already satisfied: async-generator in c:\users\raque\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\raque\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\raque\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: wcwidth in c:\users\raque\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\raque\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\raque\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (1.14.3)
# Requirement already satisfied: webencodings in c:\users\raque\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\raque\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (2.20)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\raque\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\raque\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\raque\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter==1.0.0->-r requirements/requirements.txt (line 1)) (0.17.3)

# %%
import xarray as xr
import pandas as pd
from pathlib import Path
from datetime import datetime

# %reload_ext autoreload
# %autoreload 2
# Out:
# C:\Users\raque\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# # 1. Parameters

# %%
DATA_PATH = Path("data")
RASTER_PATH = DATA_PATH / "rasters"
CSV_PATH = DATA_PATH / "csv"

# %% [markdown]
# # 2. Data

# %% [markdown]
# ## 2.1 Download data

# %%
raster_path = RASTER_PATH / "raster_test.nc"

# %% [markdown]
# ## 2.2 Load data

# %% [markdown]
# `xarray` doc: https://tutorial.xarray.dev/intro.html

# %% [markdown]
# `xarray.DataArray` is xarray’s implementation of a labeled, multi-dimensional array. It has several key properties:
#
# - values: a numpy.ndarray holding the array’s values
#
# - dims: dimension names for each axis (e.g., ('x', 'y', 'z'))
#
# - coords: a dict-like container of arrays (coordinates) that label each point (e.g., 1-dimensional arrays of numbers, datetime objects or strings)
#
# - attrs: dict to hold arbitrary metadata (attributes)

# %% [markdown]
# `xarray.Dataset`
#
# A dict-like collection of `DataArray` objects with aligned dimensions. Thus, most operations that can be performed on the dimensions of a single `DataArray` can be performed on a dataset. Datasets have data variables (see Variable below), dimensions, coordinates, and attributes.

# %% [markdown]
# ⚠️ **In the following and in all notebooks, the term raster will denominate a `xarray.DataArray` or `xarray.Dataset`** ⚠️

# %%
raster = xr.load_dataset(raster_path).drop("spatial_ref")
raster
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 5, latitude: 4, time: 365)
# Coordinates:
#   * longitude  (longitude) float64 147.1 147.2 147.3 147.4 147.5
#   * latitude   (latitude) float64 -42.34 -42.45 -42.55 -42.66
#   * time       (time) datetime64[ns] 2010-01-01 2010-01-02 ... 2010-12-31
# Data variables:
#     max_temp   (time, latitude, longitude) float32 21.72 22.02 ... 26.91 24.88
#     avg_temp   (time, latitude, longitude) float32 8.754 8.896 ... 9.257 9.204

# %% [markdown]
# Here the raster is composed of 3 coordinates (`longitude`, `latitude` and `time`) and has 2 variables:
# - `max_temp`: maximum temperature over one day
# - `avg_temp`: average temperature over one day

# %% [markdown]
# # 3. Familiarize with xarray

# %% [markdown]
# You can have a look at the xarray doc for indexing and selecting: https://docs.xarray.dev/en/stable/user-guide/indexing.html

# %% [markdown]
# #### Let's now look at the variables: for example max_temp
#
# It is a `xarray.DataArray`

# %%
raster["max_temp"]
# Out:
# <xarray.DataArray 'max_temp' (time: 365, latitude: 4, longitude: 5)>
# array([[[21.723846, 22.02069 , 22.58197 , 22.58197 , 22.947021],
#         [21.446747, 21.446747, 22.02069 , 22.355469, 22.68747 ],
#         [20.954376, 21.446747, 21.84906 , 22.209167, 22.551025],
#         [21.044403, 21.38977 , 21.946838, 22.214111, 22.200043]],
#
#        [[16.736298, 16.722961, 16.862915, 16.862915, 17.534637],
#         [16.308655, 16.308655, 16.722961, 16.632904, 16.997955],
#         [15.847961, 16.308655, 16.628693, 16.681458, 17.066895],
#         [16.705353, 17.042969, 17.556427, 19.21286 , 18.664246]],
#
#        [[16.134949, 16.129303, 16.074463, 16.074463, 16.453552],
#         [15.752319, 15.752319, 16.129303, 16.064606, 16.25592 ],
#         [15.357727, 15.752319, 16.068817, 16.187683, 16.459198],
#         [15.793091, 16.19754 , 16.703247, 18.015717, 17.67389 ]],
#
#        ...,
#
#        [[17.751251, 17.942566, 18.287933, 18.287933, 18.911102],
#         [17.08728 , 17.08728 , 17.942566, 18.043854, 18.418762],
#         [16.37619 , 17.08728 , 17.653503, 17.946106, 18.413116],
#         [16.936066, 17.548004, 18.325195, 20.108246, 19.649658]],
#
#        [[17.33136 , 17.696411, 18.419464, 18.419464, 18.840057],
#         [16.732788, 16.732788, 17.696411, 17.948914, 18.234467],
#         [15.992859, 16.732788, 17.39325 , 17.650696, 18.015717],
#         [16.350159, 17.020477, 17.799805, 18.875244, 18.554504]],
#
#        [[24.206726, 24.052002, 23.352844, 23.352844, 23.694672],
#         [24.564056, 24.564056, 24.052002, 23.88388 , 23.983765],
#         [24.23767 , 24.564056, 24.72229 , 24.669556, 24.564056],
#         [25.204803, 25.503723, 25.952484, 26.91397 , 24.878448]]],
#       dtype=float32)
# Coordinates:
#   * longitude  (longitude) float64 147.1 147.2 147.3 147.4 147.5
#   * latitude   (latitude) float64 -42.34 -42.45 -42.55 -42.66
#   * time       (time) datetime64[ns] 2010-01-01 2010-01-02 ... 2010-12-31
# Attributes:
#     grid_mapping:  spatial_ref

# %% [markdown]
# Let's say we want to select the grid cell at position [0,0], then it becomes as follows:

# %%
raster["max_temp"][dict(longitude=0, latitude=0)]
# Out:
# <xarray.DataArray 'max_temp' (time: 365)>
# array([21.723846 , 16.736298 , 16.134949 , 21.890564 , 19.672852 ,
#        15.453369 , 20.574554 , 27.85086  , 22.617828 , 25.209015 ,
#        31.450684 , 28.589386 , 16.929749 , 19.31485  , 25.19638  ,
#        22.463104 , 15.914093 , 13.77655  , 15.981598 , 18.697998 ,
#        21.062714 , 26.291504 , 14.989868 , 22.802826 , 22.937164 ,
#        19.421051 , 20.707489 , 24.69345  , 17.469208 , 24.545746 ,
#        28.896759 , 18.415253 , 28.8609   , 24.730743 , 25.048645 ,
#        18.58966  , 18.158508 , 21.311676 , 24.82077  , 28.04358  ,
#        25.897614 , 21.831482 , 17.48117  , 14.672638 , 16.884033 ,
#        21.899689 , 23.99643  , 21.082397 , 22.186676 , 24.926971 ,
#        27.600464 , 21.187195 , 17.74002  , 16.775696 , 19.028564 ,
#        24.478241 , 26.156464 , 15.266296 , 13.7034   , 15.799438 ,
#        17.3609   , 23.94226  , 27.677826 , 24.507782 , 25.237152 ,
#        25.55368  , 20.834808 , 15.811401 , 13.185028 , 17.771667 ,
#        20.22287  , 20.710327 , 22.689575 , 24.725128 , 26.18811  ,
#        25.453094 , 24.790527 , 19.61728  , 15.484314 , 12.399384 ,
#        14.02063  , 16.367035 , 18.813354 , 24.619598 , 16.769379 ,
#        13.905975 , 21.723846 , 15.513855 , 16.267883 , 17.76886  ,
#        16.778503 , 11.582062 , 12.75528  , 16.626587 , 14.071259 ,
#        17.332764 , 17.643646 , 16.789062 , 18.256287 , 18.70221  ,
# ...
#         7.9892883,  6.932831 ,  9.129425 , 12.367035 , 15.335205 ,
#        18.756378 , 17.64154  , 13.739288 , 17.512817 ,  9.580292 ,
#        10.043823 , 11.982971 , 15.752319 , 17.321503 , 17.87857  ,
#        10.657837 , 17.009216 ,  8.978912 ,  7.080536 , 10.238647 ,
#         8.502045 , 12.421173 , 15.712921 , 20.261566 , 21.103485 ,
#        12.312866 , 14.425049 , 16.377594 , 15.457611 , 15.86554  ,
#        13.509277 , 19.051788 , 21.121094 , 17.609192 , 12.461975 ,
#        13.323608 , 10.332886 , 10.318115 , 14.764069 , 16.695526 ,
#        16.045624 , 16.911438 , 19.677765 , 19.016602 , 19.386597 ,
#        24.626648 , 13.4895935, 11.357697 , 14.197876 , 14.591064 ,
#        16.804535 , 11.487122 , 14.795746 , 16.44159  , 15.427368 ,
#        23.284637 , 26.420929 , 20.284088 , 19.906372 , 18.588959 ,
#        20.005554 , 13.937622 , 17.096436 , 16.454254 , 18.75003  ,
#        20.041412 , 21.738617 , 21.188599 , 13.803284 , 16.319214 ,
#        20.97055  , 22.339996 , 19.822662 , 12.61319  , 15.52652  ,
#        13.264526 , 16.8573   , 21.749176 , 20.43039  , 16.600555 ,
#        14.206329 , 14.865356 , 13.26944  , 16.206665 , 11.892242 ,
#        18.240814 , 12.623047 , 21.609222 , 20.8721   , 12.198212 ,
#        11.373169 , 18.456024 , 17.751251 , 17.33136  , 24.206726 ],
#       dtype=float32)
# Coordinates:
#     longitude  float64 147.1
#     latitude   float64 -42.34
#   * time       (time) datetime64[ns] 2010-01-01 2010-01-02 ... 2010-12-31
# Attributes:
#     grid_mapping:  spatial_ref

# %% [markdown]
# And we can plot the timeseries over the year 2010:

# %%
raster["max_temp"][dict(longitude=0, latitude=0)].plot()

# %% [markdown]
# If we now want to get the value for July, 1st of 2010:

# %%
raster["max_temp"][dict(longitude=0, latitude=0)].sel(dict(time=datetime(2010, 7, 1))).values
# Out:
# array(8.619507, dtype=float32)

# %% [markdown]
# #### Similarly, let's say, we have the coordinates (longitude and latitude) of a point and we want to know the min and mean temperature on the 5th of December 2010:

# %% [markdown]
# The coordinates here at in the geodesic Coordinate reference system (CRS)
#
# For more info on CRS, please have a look at: https://docs.qgis.org/3.22/en/docs/gentle_gis_introduction/coordinate_reference_systems.html

# %%
point_latitude = -42.5776
point_longitude = 147.3224
point_date = datetime(2010, 12, 5)

# %%
raster.sel(
    dict(longitude=point_longitude, latitude=point_latitude, time=point_date),
    method="nearest",
)
# Out:
# <xarray.Dataset>
# Dimensions:    ()
# Coordinates:
#     longitude  float64 147.3
#     latitude   float64 -42.55
#     time       datetime64[ns] 2010-12-05
# Data variables:
#     max_temp   float32 14.41
#     avg_temp   float32 4.911

# %% [markdown]
# And let's say, you want to access the mean temperature:

# %%
point_avg_temp = raster.sel(
    dict(longitude=point_longitude, latitude=point_latitude, time=point_date),
    method="nearest",
)["avg_temp"].values
point_avg_temp
# Out:
# array(4.9108887, dtype=float32)

# %% [markdown]
# # 4. Task
#
# Your task here is to find the corresponding features associated to an ignition point. More precisely, you need to determine the elevation, population density, maximum and average temperature at the location of the ignition point and the day it occurred.

# %% [markdown]
# ## 4.1 Load data

# %% [markdown]
# ### 4.1.1 Rasters

# %%
topo_path = RASTER_PATH / "topo.nc"
weather_path = RASTER_PATH / "weather.nc"

# %%
topo_xr = xr.load_dataset(topo_path)
weather_xr = xr.load_dataset(weather_path)

# %% [markdown]
# ### 4.1.2 Ignition point

# %%
ignition_point_path = CSV_PATH / "ignition_points.csv"

# %%
df_ignition = pd.read_csv(ignition_point_path, index_col=0)
df_ignition
# Out:
#          Date  latitude  longitude
# 0  2002-11-11  -42.5618   147.4595

# %% [markdown]
# ## 4.2 Map features
#
# 🚨 You need to complement the dataframe with the raster features. 🚨
#
# You need to use the 2 rasters and extract the information corresponding to the ignition point. You have to determine the elevation, population density, maximum and average temperature at the location of the ignition point at the time of ignition.
#
# The expected result is shown below:

# %%
# We obtain the latitude, longitude and date of the ignition point
point_latitude = df_ignition["latitude"][0]
print("Latitude of the ignition point:", point_latitude)

point_longitude = df_ignition["longitude"][0]
print("Longitude of the ignition point:", point_longitude)

point_date = df_ignition["Date"][0]
print("Date of the ignition point:", point_date)


# We obtain the maximum and average temperature out of the weather raster
point_temp = weather_xr.sel(
    dict(longitude=point_longitude, latitude=point_latitude, time=point_date),
    method="nearest",
)

point_max_temp = point_temp["max_temp"].values.astype(float).tolist()
print("Maximum temperature on the day of the ignition point:", point_max_temp)

point_avg_temp = point_temp["avg_temp"].values.astype(float).tolist()
print("Average temperature on the day of the ignition point:", point_avg_temp)


# We obtain the elevation and population density out of the topo raster
point_topo = topo_xr.sel(
    dict(longitude=point_longitude, latitude=point_latitude),
    method="nearest",
)

point_elevation = int(point_topo["elevation"].values)
print("Elevation on the day of the ignition point:", point_elevation)

point_pop_dens = point_topo["pop_dens"].values[0].astype(float)
print("Population density on the day of the ignition point:", point_pop_dens) 
    
    
### Finally we create the expected data frame
df_ignition = pd.DataFrame(
    {
        "Date": {0: point_date},
        "latitude": {0: point_latitude},
        "longitude": {0: point_longitude},
        "elevation": {0: point_elevation},
        "pop_dens": {0: point_pop_dens},
        "max_temp": {0: point_max_temp},
        "avg_temp": {0: point_avg_temp},
    }
)
# Out:
# Latitude of the ignition point: -42.56179999999934
# Longitude of the ignition point: 147.459499999997
# Date of the ignition point: 2002-11-11
# Maximum temperature on the day of the ignition point: 19.283843994140625
# Average temperature on the day of the ignition point: 4.920664310455322
# Elevation on the day of the ignition point: 388
# Population density on the day of the ignition point: 2.509037494659424

# %%
expected_dataframe = pd.DataFrame(
    {
        "Date": {0: "2002-11-11"},
        "latitude": {0: -42.6},
        "longitude": {0: 147.5},
        "elevation": {0: 388},
        "pop_dens": {0: 2.5},
        "max_temp": {0: 19.3},
        "avg_temp": {0: 4.9},
    }
)

# %%
pd.testing.assert_frame_equal(df_ignition, expected_dataframe, rtol=1e-2)

# %% [markdown]
# ---
#
# # END OF SCRIPT
